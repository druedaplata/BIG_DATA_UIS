# %% [markdown]
# #  Ejecución del ejercicio 1 del problemset sobre Page Rank
#
#
# Observa cómo se ejecuta en Hadoop el ejercicio.
#
#     > hdfs dfs -mkdir -p data/matrices
#     > hdfs dfs -copyFromLocal -p data/matrices/M data/matrices
#     > hdfs dfs -copyFromLocal -p data/matrices/R_init data/matrices
#     > python files/MatmultJSON.py -r hadoop  --hadoop-streaming-jar /usr/hdp/2.2.0.0-2041//hadoop-mapreduce/hadoop-streaming.jar --hdfs-scratch-dir /tmp --output-dir hdfs:///user/user/data/matrices/R hdfs:///user/user/data/matrices/M hdfs:///user/user/data/matrices/R_init
#
# Y cómo se reporta la ejecución del mismo en las herramientas de monitoreo en Hadoop en [http://localhost:50070/](http://localhost:50070/) y en [http://localhost:19888/](http://localhost:19888/)

# %%
from IPython.display import Image
Image(filename='imgs/hadoop-3.png')

# %%
from IPython.display import Image
Image(filename='imgs/hadoop-1.png')

# %%
from IPython.display import Image
Image(filename='imgs/hadoop-2.png')

# %% [markdown]
# ## Ejercicios
#
# Ejecuta los ejercicios 2 al 4 del problem set sobre Page Rank sobre Hadoop y reporta en este notebook para cada ejercicio:
#
# 1. Los comandos usados para la ejecución
# 2. El pantallazo del JobHistory
# 3. El pantallazo de los contadores de la tarea map/reduce
# 4. El pantallazo del navegador de HDFS con los ficheros generados
#
# según se muestran en el ejemplo anterior
